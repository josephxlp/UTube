# %% [markdown]
# <a href="https://colab.research.google.com/github/josephxlp/UTube/blob/main/UtubeDownloader.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install yt-dlp --q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 170.1/170.1 kB 1.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 19.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 157.3/157.3 kB 8.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 62.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.4/194.4 kB 11.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 53.8 MB/s eta 0:00:00

# %%
from google.colab import drive
import os,sys
import shutil
import yt_dlp

# %%
drive.mount('/content/drive', force_remount=True)
rpath = "/content/drive/MyDrive/utube"
playlist_url = "https://www.youtube.com/playlist?list=PLzWjmBOf3rY3hAXmvMI1-W52a23u-3U4o"
os.chdir(rpath)
# Out:
# Mounted at /content/drive

# %%
def utube_playlist_download(playlist_url, wdir):
  os.chdir(wdir)
    # Options for yt-dlp
  ydl_opts = {
    'format': 'best',
    'outtmpl': '%(title)s.%(ext)s',
  }

  # Download the playlist
  with yt_dlp.YoutubeDL(ydl_opts) as ydl:
    ydl.download([playlist_url])

  print("Playlist downloaded successfully!")

def utube_video_download(video_url, wdir):
  os.chdir(wdir)
  pass

def rename_files():
  pass

def mp4_to_mp3():
  pass

def extract_lyrics_from_video():
  pass

def convert_audio_to_text():
  pass

# %%
utube_playlist_download(playlist_url,rpath)
# Out:
# [youtube:tab] Extracting URL: https://www.youtube.com/playlist?list=PLzWjmBOf3rY3hAXmvMI1-W52a23u-3U4o
# [youtube:tab] PLzWjmBOf3rY3hAXmvMI1-W52a23u-3U4o: Downloading webpage
# [youtube:tab] PLzWjmBOf3rY3hAXmvMI1-W52a23u-3U4o: Redownloading playlist API JSON with unavailable videos
# [download] Downloading playlist: Hinos da Harpa Cristã (Completa!)
# [youtube:tab] PLzWjmBOf3rY3hAXmvMI1-W52a23u-3U4o page 1: Downloading API JSON
# [youtube:tab] PLzWjmBOf3rY3hAXmvMI1-W52a23u-3U4o page 2: Downloading API JSON
# [youtube:tab] PLzWjmBOf3rY3hAXmvMI1-W52a23u-3U4o page 3: Downloading API JSON
# [youtube:tab] PLzWjmBOf3rY3hAXmvMI1-W52a23u-3U4o page 4: Downloading API JSON
# [youtube:tab] PLzWjmBOf3rY3hAXmvMI1-W52a23u-3U4o page 5: Downloading API JSON
# [youtube:tab] PLzWjmBOf3rY3hAXmvMI1-W52a23u-3U4o page 6: Downloading API JSON
# [youtube:tab] Playlist Hinos da Harpa Cristã (Completa!): Downloading 636 items of 636
# [download] Downloading item 1 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=QXX-O1U2ufY
# [youtube] QXX-O1U2ufY: Downloading webpage
# [youtube] QXX-O1U2ufY: Downloading ios player API JSON
# [youtube] QXX-O1U2ufY: Downloading web creator player API JSON
# [youtube] QXX-O1U2ufY: Downloading player e38bb6de
# [youtube] QXX-O1U2ufY: Downloading m3u8 information
# [info] QXX-O1U2ufY: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 001 - Chuvas De Graça.mp4
# [download] 100% of    3.74MiB in 00:00:01 at 2.94MiB/s
# [download] Downloading item 2 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Gyswv5Mat2A
# [youtube] Gyswv5Mat2A: Downloading webpage
# [youtube] Gyswv5Mat2A: Downloading ios player API JSON
# [youtube] Gyswv5Mat2A: Downloading web creator player API JSON
# [youtube] Gyswv5Mat2A: Downloading m3u8 information
# [info] Gyswv5Mat2A: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 002 - Saudosa Lembrança.mp4
# [download] 100% of    5.72MiB in 00:00:01 at 4.41MiB/s
# [download] Downloading item 3 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=KpcPiE-ihFw
# [youtube] KpcPiE-ihFw: Downloading webpage
# [youtube] KpcPiE-ihFw: Downloading ios player API JSON
# [youtube] KpcPiE-ihFw: Downloading web creator player API JSON
# [youtube] KpcPiE-ihFw: Downloading m3u8 information
# [info] KpcPiE-ihFw: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 003 - Plena Paz.mp4
# [download] 100% of    5.48MiB in 00:00:06 at 898.89KiB/s
# [download] Downloading item 4 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=pjOawdGD7mE
# [youtube] pjOawdGD7mE: Downloading webpage
# [youtube] pjOawdGD7mE: Downloading ios player API JSON
# [youtube] pjOawdGD7mE: Downloading web creator player API JSON
# [youtube] pjOawdGD7mE: Downloading m3u8 information
# [info] pjOawdGD7mE: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 004 - Deus Velará Por Ti.mp4
# [download] 100% of    7.24MiB in 00:00:05 at 1.29MiB/s
# [download] Downloading item 5 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=CRb3zmcgvPI
# [youtube] CRb3zmcgvPI: Downloading webpage
# [youtube] CRb3zmcgvPI: Downloading ios player API JSON
# [youtube] CRb3zmcgvPI: Downloading web creator player API JSON
# [youtube] CRb3zmcgvPI: Downloading m3u8 information
# [info] CRb3zmcgvPI: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 005 - Ó Desce, Fogo Santo.mp4
# [download] 100% of    2.80MiB in 00:00:01 at 1.42MiB/s
# [download] Downloading item 6 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=L2W9Dx7w2uM
# [youtube] L2W9Dx7w2uM: Downloading webpage
# [youtube] L2W9Dx7w2uM: Downloading ios player API JSON
# [youtube] L2W9Dx7w2uM: Downloading web creator player API JSON
# [youtube] L2W9Dx7w2uM: Downloading m3u8 information
# [info] L2W9Dx7w2uM: Downloading 1 format(s): 18

# %%
# Options for yt-dlp
ydl_opts = {
  'format': 'best',
  'outtmpl': '%(title)s.%(ext)s',
}

# Download the playlist
with yt_dlp.YoutubeDL(ydl_opts) as ydl:
  ydl.download([playlist_url])
# Out:
# [youtube:tab] Extracting URL: https://www.youtube.com/playlist?list=PLzWjmBOf3rY3hAXmvMI1-W52a23u-3U4o
# [youtube:tab] PLzWjmBOf3rY3hAXmvMI1-W52a23u-3U4o: Downloading webpage
# [youtube:tab] PLzWjmBOf3rY3hAXmvMI1-W52a23u-3U4o: Redownloading playlist API JSON with unavailable videos
# [download] Downloading playlist: Hinos da Harpa Cristã (Completa!)
# [youtube:tab] PLzWjmBOf3rY3hAXmvMI1-W52a23u-3U4o page 1: Downloading API JSON
# [youtube:tab] PLzWjmBOf3rY3hAXmvMI1-W52a23u-3U4o page 2: Downloading API JSON
# [youtube:tab] PLzWjmBOf3rY3hAXmvMI1-W52a23u-3U4o page 3: Downloading API JSON
# [youtube:tab] PLzWjmBOf3rY3hAXmvMI1-W52a23u-3U4o page 4: Downloading API JSON
# [youtube:tab] PLzWjmBOf3rY3hAXmvMI1-W52a23u-3U4o page 5: Downloading API JSON
# [youtube:tab] PLzWjmBOf3rY3hAXmvMI1-W52a23u-3U4o page 6: Downloading API JSON
# [youtube:tab] Playlist Hinos da Harpa Cristã (Completa!): Downloading 636 items of 636
# [download] Downloading item 1 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=QXX-O1U2ufY
# [youtube] QXX-O1U2ufY: Downloading webpage
# [youtube] QXX-O1U2ufY: Downloading ios player API JSON
# [youtube] QXX-O1U2ufY: Downloading web creator player API JSON
# [youtube] QXX-O1U2ufY: Downloading player 5f8f5b0f
# [youtube] QXX-O1U2ufY: Downloading m3u8 information
# [info] QXX-O1U2ufY: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 001 - Chuvas De Graça.mp4
# [download] 100% of    3.74MiB in 00:00:01 at 2.99MiB/s
# [download] Downloading item 2 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Gyswv5Mat2A
# [youtube] Gyswv5Mat2A: Downloading webpage
# [youtube] Gyswv5Mat2A: Downloading ios player API JSON
# [youtube] Gyswv5Mat2A: Downloading web creator player API JSON
# [youtube] Gyswv5Mat2A: Downloading m3u8 information
# [info] Gyswv5Mat2A: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 002 - Saudosa Lembrança.mp4
# [download] 100% of    5.72MiB in 00:00:01 at 4.51MiB/s
# [download] Downloading item 3 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=KpcPiE-ihFw
# [youtube] KpcPiE-ihFw: Downloading webpage
# [youtube] KpcPiE-ihFw: Downloading ios player API JSON
# [youtube] KpcPiE-ihFw: Downloading web creator player API JSON
# [youtube] KpcPiE-ihFw: Downloading m3u8 information
# [info] KpcPiE-ihFw: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 003 - Plena Paz.mp4
# [download] 100% of    5.48MiB in 00:00:04 at 1.28MiB/s
# [download] Downloading item 4 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=pjOawdGD7mE
# [youtube] pjOawdGD7mE: Downloading webpage
# [youtube] pjOawdGD7mE: Downloading ios player API JSON
# [youtube] pjOawdGD7mE: Downloading web creator player API JSON
# [youtube] pjOawdGD7mE: Downloading m3u8 information
# [info] pjOawdGD7mE: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 004 - Deus Velará Por Ti.mp4
# [download] 100% of    7.24MiB in 00:00:03 at 2.28MiB/s
# [download] Downloading item 5 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=CRb3zmcgvPI
# [youtube] CRb3zmcgvPI: Downloading webpage
# [youtube] CRb3zmcgvPI: Downloading ios player API JSON
# [youtube] CRb3zmcgvPI: Downloading web creator player API JSON
# [youtube] CRb3zmcgvPI: Downloading m3u8 information
# [info] CRb3zmcgvPI: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 005 - Ó Desce, Fogo Santo.mp4
# [download] 100% of    2.80MiB in 00:00:01 at 1.61MiB/s
# [download] Downloading item 6 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=L2W9Dx7w2uM
# [youtube] L2W9Dx7w2uM: Downloading webpage
# [youtube] L2W9Dx7w2uM: Downloading ios player API JSON
# [youtube] L2W9Dx7w2uM: Downloading web creator player API JSON
# [youtube] L2W9Dx7w2uM: Downloading m3u8 information
# [info] L2W9Dx7w2uM: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 006 - Na Maldição Da Cruz.mp4
# [download] 100% of    4.40MiB in 00:00:02 at 2.00MiB/s
# [download] Downloading item 7 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=vL6ejBm1rnw
# [youtube] vL6ejBm1rnw: Downloading webpage
# [youtube] vL6ejBm1rnw: Downloading ios player API JSON
# [youtube] vL6ejBm1rnw: Downloading web creator player API JSON
# [youtube] vL6ejBm1rnw: Downloading m3u8 information
# [info] vL6ejBm1rnw: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 007 - Cristo Cura, Sim!.mp4
# [download] 100% of    3.62MiB in 00:00:02 at 1.28MiB/s
# [download] Downloading item 8 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=w-IhD6Ue538
# [youtube] w-IhD6Ue538: Downloading webpage
# [youtube] w-IhD6Ue538: Downloading ios player API JSON
# [youtube] w-IhD6Ue538: Downloading web creator player API JSON
# [youtube] w-IhD6Ue538: Downloading m3u8 information
# [info] w-IhD6Ue538: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 008 - Cristo, O Fiel Amigo.mp4
# [download] 100% of    5.01MiB in 00:00:02 at 1.70MiB/s
# [download] Downloading item 9 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=ftrHqiCcEII
# [youtube] ftrHqiCcEII: Downloading webpage
# [youtube] ftrHqiCcEII: Downloading ios player API JSON
# [youtube] ftrHqiCcEII: Downloading web creator player API JSON
# [youtube] ftrHqiCcEII: Downloading m3u8 information
# [info] ftrHqiCcEII: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 009 - Marchai, Soldados de Cristo.mp4
# [download] 100% of    4.07MiB in 00:00:02 at 1.74MiB/s
# [download] Downloading item 10 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=9jwKNFFzsOQ
# [youtube] 9jwKNFFzsOQ: Downloading webpage
# [youtube] 9jwKNFFzsOQ: Downloading ios player API JSON
# [youtube] 9jwKNFFzsOQ: Downloading web creator player API JSON
# [youtube] 9jwKNFFzsOQ: Downloading m3u8 information
# [info] 9jwKNFFzsOQ: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 010 - Eu Te Louvo.mp4
# [download] 100% of    4.16MiB in 00:00:02 at 1.50MiB/s
# [download] Downloading item 11 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=qf4SMvWTjq4
# [youtube] qf4SMvWTjq4: Downloading webpage
# [youtube] qf4SMvWTjq4: Downloading ios player API JSON
# [youtube] qf4SMvWTjq4: Downloading web creator player API JSON
# [youtube] qf4SMvWTjq4: Downloading m3u8 information
# [info] qf4SMvWTjq4: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 011 - Ó Cristão, Eia Avante.mp4
# [download] 100% of    5.84MiB in 00:00:02 at 2.90MiB/s
# [download] Downloading item 12 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=aL3kYcfEi38
# [youtube] aL3kYcfEi38: Downloading webpage
# [youtube] aL3kYcfEi38: Downloading ios player API JSON
# [youtube] aL3kYcfEi38: Downloading web creator player API JSON
# [youtube] aL3kYcfEi38: Downloading m3u8 information
# [info] aL3kYcfEi38: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 012 - Vem Já, Pecador.mp4
# [download] 100% of    5.70MiB in 00:00:03 at 1.48MiB/s
# [download] Downloading item 13 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=juzSQybf2OI
# [youtube] juzSQybf2OI: Downloading webpage
# [youtube] juzSQybf2OI: Downloading ios player API JSON
# [youtube] juzSQybf2OI: Downloading web creator player API JSON
# [youtube] juzSQybf2OI: Downloading m3u8 information
# [info] juzSQybf2OI: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 013 - Jesus Comprou-Me.mp4
# [download] 100% of    4.43MiB in 00:00:04 at 1.04MiB/s
# [download] Downloading item 14 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=sI8MF-N4wvI
# [youtube] sI8MF-N4wvI: Downloading webpage
# [youtube] sI8MF-N4wvI: Downloading ios player API JSON
# [youtube] sI8MF-N4wvI: Downloading web creator player API JSON
# [youtube] sI8MF-N4wvI: Downloading m3u8 information
# [info] sI8MF-N4wvI: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 014 - Gozo em Jesus.mp4
# [download] 100% of    5.35MiB in 00:00:03 at 1.67MiB/s
# [download] Downloading item 15 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=U8-AMxCsJtE
# [youtube] U8-AMxCsJtE: Downloading webpage
# [youtube] U8-AMxCsJtE: Downloading ios player API JSON
# [youtube] U8-AMxCsJtE: Downloading web creator player API JSON
# [youtube] U8-AMxCsJtE: Downloading m3u8 information
# [info] U8-AMxCsJtE: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 015 - Conversão.mp4
# [download] 100% of    5.63MiB in 00:00:02 at 1.90MiB/s
# [download] Downloading item 16 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=kRCXGO7JhoE
# [youtube] kRCXGO7JhoE: Downloading webpage
# [youtube] kRCXGO7JhoE: Downloading ios player API JSON
# [youtube] kRCXGO7JhoE: Downloading web creator player API JSON
# [youtube] kRCXGO7JhoE: Downloading m3u8 information
# [info] kRCXGO7JhoE: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 016 - Despertar Para O Trabalho.mp4
# [download] 100% of    4.62MiB in 00:00:03 at 1.34MiB/s
# [download] Downloading item 17 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=xfRRanUmOFQ
# [youtube] xfRRanUmOFQ: Downloading webpage
# [youtube] xfRRanUmOFQ: Downloading ios player API JSON
# [youtube] xfRRanUmOFQ: Downloading web creator player API JSON
# [youtube] xfRRanUmOFQ: Downloading m3u8 information
# [info] xfRRanUmOFQ: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 017 - Pensando Em Jesus.mp4
# [download] 100% of    3.32MiB in 00:00:02 at 1.15MiB/s
# [download] Downloading item 18 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Loql__9ATvw
# [youtube] Loql__9ATvw: Downloading webpage
# [youtube] Loql__9ATvw: Downloading ios player API JSON
# [youtube] Loql__9ATvw: Downloading web creator player API JSON
# [youtube] Loql__9ATvw: Downloading m3u8 information
# [info] Loql__9ATvw: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 018 - Grata Nova.mp4
# [download] 100% of    4.40MiB in 00:00:03 at 1.45MiB/s
# [download] Downloading item 19 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=pl7L5H4BNoA
# [youtube] pl7L5H4BNoA: Downloading webpage
# [youtube] pl7L5H4BNoA: Downloading ios player API JSON
# [youtube] pl7L5H4BNoA: Downloading web creator player API JSON
# [youtube] pl7L5H4BNoA: Downloading m3u8 information
# [info] pl7L5H4BNoA: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 019 - O Convite de Cristo.mp4
# [download] 100% of    3.13MiB in 00:00:02 at 1.08MiB/s
# [download] Downloading item 20 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=C197_AvTXu4
# [youtube] C197_AvTXu4: Downloading webpage
# [youtube] C197_AvTXu4: Downloading ios player API JSON
# [youtube] C197_AvTXu4: Downloading web creator player API JSON
# [youtube] C197_AvTXu4: Downloading m3u8 information
# [info] C197_AvTXu4: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 020 - Olhai P'ra O Cordeiro De Deus.mp4
# [download] 100% of    4.48MiB in 00:00:04 at 944.53KiB/s
# [download] Downloading item 21 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=VYIy9XB6zUU
# [youtube] VYIy9XB6zUU: Downloading webpage
# [youtube] VYIy9XB6zUU: Downloading ios player API JSON
# [youtube] VYIy9XB6zUU: Downloading web creator player API JSON
# [youtube] VYIy9XB6zUU: Downloading m3u8 information
# [info] VYIy9XB6zUU: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 021 - Gloriosa Aurora.mp4
# [download] 100% of    4.47MiB in 00:00:03 at 1.12MiB/s
# [download] Downloading item 22 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=bpuvPoEVyDM
# [youtube] bpuvPoEVyDM: Downloading webpage
# [youtube] bpuvPoEVyDM: Downloading ios player API JSON
# [youtube] bpuvPoEVyDM: Downloading web creator player API JSON
# [youtube] bpuvPoEVyDM: Downloading m3u8 information
# [info] bpuvPoEVyDM: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 022 - Ceia Do Senhor.mp4
# [download] 100% of    3.81MiB in 00:00:02 at 1.45MiB/s
# [download] Downloading item 23 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=u9C8VCWKADs
# [youtube] u9C8VCWKADs: Downloading webpage
# [youtube] u9C8VCWKADs: Downloading ios player API JSON
# [youtube] u9C8VCWKADs: Downloading web creator player API JSON
# [youtube] u9C8VCWKADs: Downloading m3u8 information
# [info] u9C8VCWKADs: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 023 - Glória A Jesus.mp4
# [download] 100% of    2.86MiB in 00:00:03 at 738.43KiB/s
# [download] Downloading item 24 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=x3qRkOr0ma4
# [youtube] x3qRkOr0ma4: Downloading webpage
# [youtube] x3qRkOr0ma4: Downloading ios player API JSON
# [youtube] x3qRkOr0ma4: Downloading web creator player API JSON
# [youtube] x3qRkOr0ma4: Downloading m3u8 information
# [info] x3qRkOr0ma4: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 024 - Poder Pentecostal.mp4
# [download] 100% of    5.03MiB in 00:00:03 at 1.33MiB/s
# [download] Downloading item 25 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=UFVuso9DOxk
# [youtube] UFVuso9DOxk: Downloading webpage
# [youtube] UFVuso9DOxk: Downloading ios player API JSON
# [youtube] UFVuso9DOxk: Downloading web creator player API JSON
# [youtube] UFVuso9DOxk: Downloading m3u8 information
# [info] UFVuso9DOxk: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 025 - Jesus, Tu És Bom.mp4
# [download] 100% of    3.98MiB in 00:00:02 at 1.65MiB/s
# [download] Downloading item 26 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=0Hw2XI0fE5U
# [youtube] 0Hw2XI0fE5U: Downloading webpage
# [youtube] 0Hw2XI0fE5U: Downloading ios player API JSON
# [youtube] 0Hw2XI0fE5U: Downloading web creator player API JSON
# [youtube] 0Hw2XI0fE5U: Downloading m3u8 information
# [info] 0Hw2XI0fE5U: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 026 - A Formosa Jerusalém.mp4
# [download] 100% of    5.89MiB in 00:00:03 at 1.55MiB/s
# [download] Downloading item 27 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=1eMaFXp143E
# [youtube] 1eMaFXp143E: Downloading webpage
# [youtube] 1eMaFXp143E: Downloading ios player API JSON
# [youtube] 1eMaFXp143E: Downloading web creator player API JSON
# [youtube] 1eMaFXp143E: Downloading m3u8 information
# [info] 1eMaFXp143E: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 027 - Amor Que Vence.mp4
# [download] 100% of    3.41MiB in 00:00:02 at 1.20MiB/s
# [download] Downloading item 28 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=0uWVX6G-w_k
# [youtube] 0uWVX6G-w_k: Downloading webpage
# [youtube] 0uWVX6G-w_k: Downloading ios player API JSON
# [youtube] 0uWVX6G-w_k: Downloading web creator player API JSON
# [youtube] 0uWVX6G-w_k: Downloading m3u8 information
# [info] 0uWVX6G-w_k: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 028 - Deus Vai Te Guiar.mp4
# [download] 100% of    3.81MiB in 00:00:02 at 1.30MiB/s
# [download] Downloading item 29 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=kGv3aD4HaeA
# [youtube] kGv3aD4HaeA: Downloading webpage
# [youtube] kGv3aD4HaeA: Downloading ios player API JSON
# [youtube] kGv3aD4HaeA: Downloading web creator player API JSON
# [youtube] kGv3aD4HaeA: Downloading m3u8 information
# [info] kGv3aD4HaeA: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 029 - O Precioso Sangue.mp4
# [download] 100% of    3.75MiB in 00:00:02 at 1.32MiB/s
# [download] Downloading item 30 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=N08zezz3sWE
# [youtube] N08zezz3sWE: Downloading webpage
# [youtube] N08zezz3sWE: Downloading ios player API JSON
# [youtube] N08zezz3sWE: Downloading web creator player API JSON
# [youtube] N08zezz3sWE: Downloading m3u8 information
# [info] N08zezz3sWE: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 030 - Não Sou Meu.mp4
# [download] 100% of    3.21MiB in 00:00:02 at 1.21MiB/s
# [download] Downloading item 31 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=CVDtt5g0Un8
# [youtube] CVDtt5g0Un8: Downloading webpage
# [youtube] CVDtt5g0Un8: Downloading ios player API JSON
# [youtube] CVDtt5g0Un8: Downloading web creator player API JSON
# [youtube] CVDtt5g0Un8: Downloading m3u8 information
# [info] CVDtt5g0Un8: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 031 - Glória Ao Meu Jesus.mp4
# [download] 100% of    3.83MiB in 00:00:02 at 1.36MiB/s
# [download] Downloading item 32 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=XCDqsAa8UeM
# [youtube] XCDqsAa8UeM: Downloading webpage
# [youtube] XCDqsAa8UeM: Downloading ios player API JSON
# [youtube] XCDqsAa8UeM: Downloading web creator player API JSON
# [youtube] XCDqsAa8UeM: Downloading m3u8 information
# [info] XCDqsAa8UeM: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 032 - Meu Cristo! Meu Cristo!.mp4
# [download] 100% of    5.59MiB in 00:00:03 at 1.49MiB/s
# [download] Downloading item 33 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=8KKZZd9NYMM
# [youtube] 8KKZZd9NYMM: Downloading webpage
# [youtube] 8KKZZd9NYMM: Downloading ios player API JSON
# [youtube] 8KKZZd9NYMM: Downloading web creator player API JSON
# [youtube] 8KKZZd9NYMM: Downloading m3u8 information
# [info] 8KKZZd9NYMM: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 033 - Com Tua Mão Segura.mp4
# [download] 100% of    4.25MiB in 00:00:01 at 3.78MiB/s
# [download] Downloading item 34 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=8_GXhpzyn5g
# [youtube] 8_GXhpzyn5g: Downloading webpage
# [youtube] 8_GXhpzyn5g: Downloading ios player API JSON
# [youtube] 8_GXhpzyn5g: Downloading web creator player API JSON
# [youtube] 8_GXhpzyn5g: Downloading m3u8 information
# [info] 8_GXhpzyn5g: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 034 - Milícia De Jesus.mp4
# [download] 100% of    3.36MiB in 00:00:02 at 1.47MiB/s
# [download] Downloading item 35 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Qzo3Nv_hnOM
# [youtube] Qzo3Nv_hnOM: Downloading webpage
# [youtube] Qzo3Nv_hnOM: Downloading ios player API JSON
# [youtube] Qzo3Nv_hnOM: Downloading web creator player API JSON
# [youtube] Qzo3Nv_hnOM: Downloading m3u8 information
# [info] Qzo3Nv_hnOM: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 035 - O Grande Amor.mp4
# [download] 100% of    5.09MiB in 00:00:02 at 2.12MiB/s
# [download] Downloading item 36 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=BbyjaiJdQy4
# [youtube] BbyjaiJdQy4: Downloading webpage
# [youtube] BbyjaiJdQy4: Downloading ios player API JSON
# [youtube] BbyjaiJdQy4: Downloading web creator player API JSON
# [youtube] BbyjaiJdQy4: Downloading m3u8 information
# [info] BbyjaiJdQy4: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 036 - O Exilado.mp4
# [download] 100% of    7.59MiB in 00:00:05 at 1.46MiB/s
# [download] Downloading item 37 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=eZLKhiQUvlw
# [youtube] eZLKhiQUvlw: Downloading webpage
# [youtube] eZLKhiQUvlw: Downloading ios player API JSON
# [youtube] eZLKhiQUvlw: Downloading web creator player API JSON
# [youtube] eZLKhiQUvlw: Downloading m3u8 information
# [info] eZLKhiQUvlw: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 037 - Cristo P'ra Mim.mp4
# [download] 100% of    5.95MiB in 00:00:02 at 2.05MiB/s
# [download] Downloading item 38 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=BJdMln8aJ3s
# [youtube] BJdMln8aJ3s: Downloading webpage
# [youtube] BJdMln8aJ3s: Downloading ios player API JSON
# [youtube] BJdMln8aJ3s: Downloading web creator player API JSON
# [youtube] BJdMln8aJ3s: Downloading m3u8 information
# [info] BJdMln8aJ3s: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 038 - O Senhor É Rei.mp4
# [download] 100% of    4.08MiB in 00:00:03 at 1.22MiB/s
# [download] Downloading item 39 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=GdmZSU5dk-o
# [youtube] GdmZSU5dk-o: Downloading webpage
# [youtube] GdmZSU5dk-o: Downloading ios player API JSON
# [youtube] GdmZSU5dk-o: Downloading web creator player API JSON
# [youtube] GdmZSU5dk-o: Downloading m3u8 information
# [info] GdmZSU5dk-o: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 039 - Alvo Mais Que A Neve.mp4
# [download] 100% of    6.14MiB in 00:00:04 at 1.37MiB/s
# [download] Downloading item 40 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=xoi-BUcjC1Q
# [youtube] xoi-BUcjC1Q: Downloading webpage
# [youtube] xoi-BUcjC1Q: Downloading ios player API JSON
# [youtube] xoi-BUcjC1Q: Downloading web creator player API JSON
# [youtube] xoi-BUcjC1Q: Downloading m3u8 information
# [info] xoi-BUcjC1Q: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 040 - A Cidade Do Bom Deus.mp4
# [download] 100% of    5.38MiB in 00:00:03 at 1.42MiB/s
# [download] Downloading item 41 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=MntVLPhu5g8
# [youtube] MntVLPhu5g8: Downloading webpage
# [youtube] MntVLPhu5g8: Downloading ios player API JSON
# [youtube] MntVLPhu5g8: Downloading web creator player API JSON
# [youtube] MntVLPhu5g8: Downloading m3u8 information
# [info] MntVLPhu5g8: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 041 - A Cristo Coroai.mp4
# [download] 100% of    4.28MiB in 00:00:03 at 1.35MiB/s
# [download] Downloading item 42 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=-4eAqkXQUd4
# [youtube] -4eAqkXQUd4: Downloading webpage
# [youtube] -4eAqkXQUd4: Downloading ios player API JSON
# [youtube] -4eAqkXQUd4: Downloading web creator player API JSON
# [youtube] -4eAqkXQUd4: Downloading m3u8 information
# [info] -4eAqkXQUd4: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 042 - Saudai Jesus.mp4
# [download] 100% of    4.33MiB in 00:00:02 at 1.46MiB/s
# [download] Downloading item 43 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=TNPwaEvbw_8
# [youtube] TNPwaEvbw_8: Downloading webpage
# [youtube] TNPwaEvbw_8: Downloading ios player API JSON
# [youtube] TNPwaEvbw_8: Downloading web creator player API JSON
# [youtube] TNPwaEvbw_8: Downloading m3u8 information
# [info] TNPwaEvbw_8: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 043 - Doce Lar.mp4
# [download] 100% of    6.88MiB in 00:00:02 at 3.22MiB/s
# [download] Downloading item 44 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=8E4O6PdwxtA
# [youtube] 8E4O6PdwxtA: Downloading webpage
# [youtube] 8E4O6PdwxtA: Downloading ios player API JSON
# [youtube] 8E4O6PdwxtA: Downloading web creator player API JSON
# [youtube] 8E4O6PdwxtA: Downloading m3u8 information
# [info] 8E4O6PdwxtA: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 044 - Oh! Que Glória.mp4
# [download] 100% of    4.96MiB in 00:00:02 at 2.31MiB/s
# [download] Downloading item 45 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=G0RrWwh37hc
# [youtube] G0RrWwh37hc: Downloading webpage
# [youtube] G0RrWwh37hc: Downloading ios player API JSON
# [youtube] G0RrWwh37hc: Downloading web creator player API JSON
# [youtube] G0RrWwh37hc: Downloading m3u8 information
# [info] G0RrWwh37hc: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 045 - Redentor Onipotente.mp4
# [download] 100% of    6.55MiB in 00:00:05 at 1.26MiB/s
# [download] Downloading item 46 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=PxSbuOPusf8
# [youtube] PxSbuOPusf8: Downloading webpage
# [youtube] PxSbuOPusf8: Downloading ios player API JSON
# [youtube] PxSbuOPusf8: Downloading web creator player API JSON
# [youtube] PxSbuOPusf8: Downloading m3u8 information
# [info] PxSbuOPusf8: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 046 - Um Pendão Real.mp4
# [download] 100% of    4.49MiB in 00:00:02 at 1.69MiB/s
# [download] Downloading item 47 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=bgeWFNXNY38
# [youtube] bgeWFNXNY38: Downloading webpage
# [youtube] bgeWFNXNY38: Downloading ios player API JSON
# [youtube] bgeWFNXNY38: Downloading web creator player API JSON
# [youtube] bgeWFNXNY38: Downloading m3u8 information
# [info] bgeWFNXNY38: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 047 - Rocha Eterna.mp4
# [download] 100% of    3.95MiB in 00:00:01 at 2.02MiB/s
# [download] Downloading item 48 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=J4V-64P6_CA
# [youtube] J4V-64P6_CA: Downloading webpage
# [youtube] J4V-64P6_CA: Downloading ios player API JSON
# [youtube] J4V-64P6_CA: Downloading web creator player API JSON
# [youtube] J4V-64P6_CA: Downloading m3u8 information
# [info] J4V-64P6_CA: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 048 - O Dia Do Triunfo De Jesus.mp4
# [download] 100% of    4.27MiB in 00:00:02 at 1.45MiB/s
# [download] Downloading item 49 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Sb-CHaqFDtM
# [youtube] Sb-CHaqFDtM: Downloading webpage
# [youtube] Sb-CHaqFDtM: Downloading ios player API JSON
# [youtube] Sb-CHaqFDtM: Downloading web creator player API JSON
# [youtube] Sb-CHaqFDtM: Downloading m3u8 information
# [info] Sb-CHaqFDtM: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 049 - Aleluia! Já Creio.mp4
# [download] 100% of    2.97MiB in 00:00:02 at 1.09MiB/s
# [download] Downloading item 50 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=3bjzDsyEumQ
# [youtube] 3bjzDsyEumQ: Downloading webpage
# [youtube] 3bjzDsyEumQ: Downloading ios player API JSON
# [youtube] 3bjzDsyEumQ: Downloading web creator player API JSON
# [youtube] 3bjzDsyEumQ: Downloading m3u8 information
# [info] 3bjzDsyEumQ: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 050 - Sempre Fiéis.mp4
# [download] 100% of    4.09MiB in 00:00:03 at 1.26MiB/s
# [download] Downloading item 51 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=NhCzuBKFeD8
# [youtube] NhCzuBKFeD8: Downloading webpage
# [youtube] NhCzuBKFeD8: Downloading ios player API JSON
# [youtube] NhCzuBKFeD8: Downloading web creator player API JSON
# [youtube] NhCzuBKFeD8: Downloading m3u8 information
# [info] NhCzuBKFeD8: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 051 - Adoração Reconhecida.mp4
# [download] 100% of    3.18MiB in 00:00:02 at 1.18MiB/s
# [download] Downloading item 52 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=gCK5T-tjPhk
# [youtube] gCK5T-tjPhk: Downloading webpage
# [youtube] gCK5T-tjPhk: Downloading ios player API JSON
# [youtube] gCK5T-tjPhk: Downloading web creator player API JSON
# [youtube] gCK5T-tjPhk: Downloading m3u8 information
# [info] gCK5T-tjPhk: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 052 - Tudo Está Bem.mp4
# [download] 100% of    6.12MiB in 00:00:03 at 1.78MiB/s
# [download] Downloading item 53 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=JmIU82KPhrs
# [youtube] JmIU82KPhrs: Downloading webpage
# [youtube] JmIU82KPhrs: Downloading ios player API JSON
# [youtube] JmIU82KPhrs: Downloading web creator player API JSON
# [youtube] JmIU82KPhrs: Downloading m3u8 information
# [info] JmIU82KPhrs: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 053 - A Esperança da Igreja.mp4
# [download] 100% of    5.36MiB in 00:00:01 at 2.69MiB/s
# [download] Downloading item 54 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=e_QiP1Xy8DQ
# [youtube] e_QiP1Xy8DQ: Downloading webpage
# [youtube] e_QiP1Xy8DQ: Downloading ios player API JSON
# [youtube] e_QiP1Xy8DQ: Downloading web creator player API JSON
# [youtube] e_QiP1Xy8DQ: Downloading m3u8 information
# [info] e_QiP1Xy8DQ: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 054 - Louvemos ao Redentor.mp4
# [download] 100% of    3.63MiB in 00:00:02 at 1.31MiB/s
# [download] Downloading item 55 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=GMevddT7cWA
# [youtube] GMevddT7cWA: Downloading webpage
# [youtube] GMevddT7cWA: Downloading ios player API JSON
# [youtube] GMevddT7cWA: Downloading web creator player API JSON
# [youtube] GMevddT7cWA: Downloading m3u8 information
# [info] GMevddT7cWA: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 055 - Mais Perto da Tua Cruz.mp4
# [download] 100% of    3.32MiB in 00:00:01 at 1.66MiB/s
# [download] Downloading item 56 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=qIZEcYfwN88
# [youtube] qIZEcYfwN88: Downloading webpage
# [youtube] qIZEcYfwN88: Downloading ios player API JSON
# [youtube] qIZEcYfwN88: Downloading web creator player API JSON
# [youtube] qIZEcYfwN88: Downloading m3u8 information
# [info] qIZEcYfwN88: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 056 - Tudo Em Cristo.mp4
# [download] 100% of    7.13MiB in 00:00:04 at 1.43MiB/s
# [download] Downloading item 57 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=mjgbQbbnrFw
# [youtube] mjgbQbbnrFw: Downloading webpage
# [youtube] mjgbQbbnrFw: Downloading ios player API JSON
# [youtube] mjgbQbbnrFw: Downloading web creator player API JSON
# [youtube] mjgbQbbnrFw: Downloading m3u8 information
# [info] mjgbQbbnrFw: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 057 - Vivifica nos, Senhor.mp4
# [download] 100% of    3.50MiB in 00:00:01 at 1.76MiB/s
# [download] Downloading item 58 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=vMQ3_4gc0p4
# [youtube] vMQ3_4gc0p4: Downloading webpage
# [youtube] vMQ3_4gc0p4: Downloading ios player API JSON
# [youtube] vMQ3_4gc0p4: Downloading web creator player API JSON
# [youtube] vMQ3_4gc0p4: Downloading m3u8 information
# [info] vMQ3_4gc0p4: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 058 - Não Temas.mp4
# [download] 100% of    5.46MiB in 00:00:04 at 1.27MiB/s
# [download] Downloading item 59 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Ml2sbzaHi_U
# [youtube] Ml2sbzaHi_U: Downloading webpage
# [youtube] Ml2sbzaHi_U: Downloading ios player API JSON
# [youtube] Ml2sbzaHi_U: Downloading web creator player API JSON
# [youtube] Ml2sbzaHi_U: Downloading m3u8 information
# [info] Ml2sbzaHi_U: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 059 - Eu Creio, Sim.mp4
# [download] 100% of    3.13MiB in 00:00:02 at 1.13MiB/s
# [download] Downloading item 60 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=SpWShEBv2HQ
# [youtube] SpWShEBv2HQ: Downloading webpage
# [youtube] SpWShEBv2HQ: Downloading ios player API JSON
# [youtube] SpWShEBv2HQ: Downloading web creator player API JSON
# [youtube] SpWShEBv2HQ: Downloading m3u8 information
# [info] SpWShEBv2HQ: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 060 - Exultação Do Crente.mp4
# [download] 100% of    4.44MiB in 00:00:03 at 1.20MiB/s
# [download] Downloading item 61 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=2ly3HJ6aR2k
# [youtube] 2ly3HJ6aR2k: Downloading webpage
# [youtube] 2ly3HJ6aR2k: Downloading ios player API JSON
# [youtube] 2ly3HJ6aR2k: Downloading web creator player API JSON
# [youtube] 2ly3HJ6aR2k: Downloading m3u8 information
# [info] 2ly3HJ6aR2k: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 061 - Deus Tomará Conta De Ti.mp4
# [download] 100% of    4.35MiB in 00:00:02 at 1.81MiB/s
# [download] Downloading item 62 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=GcRI_iVv3bU
# [youtube] GcRI_iVv3bU: Downloading webpage
# [youtube] GcRI_iVv3bU: Downloading ios player API JSON
# [youtube] GcRI_iVv3bU: Downloading web creator player API JSON
# [youtube] GcRI_iVv3bU: Downloading m3u8 information
# [info] GcRI_iVv3bU: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 062 - Achei Jesus.mp4
# [download] 100% of    5.35MiB in 00:00:04 at 1.29MiB/s
# [download] Downloading item 63 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=czOPT-1zDIw
# [youtube] czOPT-1zDIw: Downloading webpage
# [youtube] czOPT-1zDIw: Downloading ios player API JSON
# [youtube] czOPT-1zDIw: Downloading web creator player API JSON
# [youtube] czOPT-1zDIw: Downloading m3u8 information
# [info] czOPT-1zDIw: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 063 - Acordai! Acordai.mp4
# [download] 100% of    6.27MiB in 00:00:00 at 8.25MiB/s
# [download] Downloading item 64 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=3CacUcei4MU
# [youtube] 3CacUcei4MU: Downloading webpage
# [youtube] 3CacUcei4MU: Downloading ios player API JSON
# [youtube] 3CacUcei4MU: Downloading web creator player API JSON
# [youtube] 3CacUcei4MU: Downloading m3u8 information
# [info] 3CacUcei4MU: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 064 - De Todo O Mundo： Aleluia!.mp4
# [download] 100% of    4.19MiB in 00:00:04 at 1022.34KiB/s
# [download] Downloading item 65 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=o63dSCdvvoM
# [youtube] o63dSCdvvoM: Downloading webpage
# [youtube] o63dSCdvvoM: Downloading ios player API JSON
# [youtube] o63dSCdvvoM: Downloading web creator player API JSON
# [youtube] o63dSCdvvoM: Downloading m3u8 information
# [info] o63dSCdvvoM: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 065 - Quem Irá？.mp4
# [download] 100% of    4.62MiB in 00:00:02 at 1.62MiB/s
# [download] Downloading item 66 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=64xe6b2YP8A
# [youtube] 64xe6b2YP8A: Downloading webpage
# [youtube] 64xe6b2YP8A: Downloading ios player API JSON
# [youtube] 64xe6b2YP8A: Downloading web creator player API JSON
# [youtube] 64xe6b2YP8A: Downloading m3u8 information
# [info] 64xe6b2YP8A: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 066 - Pronto A Salvar.mp4
# [download] 100% of    1.76MiB in 00:00:02 at 751.01KiB/s
# [download] Downloading item 67 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=LOL69n8T3B4
# [youtube] LOL69n8T3B4: Downloading webpage
# [youtube] LOL69n8T3B4: Downloading ios player API JSON
# [youtube] LOL69n8T3B4: Downloading web creator player API JSON
# [youtube] LOL69n8T3B4: Downloading m3u8 information
# [info] LOL69n8T3B4: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 067 - Quem Quer Ir Com Cristo？.mp4
# [download] 100% of    3.30MiB in 00:00:03 at 1.04MiB/s
# [download] Downloading item 68 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=sZ-Ku0pCCE8
# [youtube] sZ-Ku0pCCE8: Downloading webpage
# [youtube] sZ-Ku0pCCE8: Downloading ios player API JSON
# [youtube] sZ-Ku0pCCE8: Downloading web creator player API JSON
# [youtube] sZ-Ku0pCCE8: Downloading m3u8 information
# [info] sZ-Ku0pCCE8: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 068 - Gozo de Ter Salvação.mp4
# [download] 100% of    3.84MiB in 00:00:02 at 1.37MiB/s
# [download] Downloading item 69 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=NIrIxkhp9uc
# [youtube] NIrIxkhp9uc: Downloading webpage
# [youtube] NIrIxkhp9uc: Downloading ios player API JSON
# [youtube] NIrIxkhp9uc: Downloading web creator player API JSON
# [youtube] NIrIxkhp9uc: Downloading m3u8 information
# [info] NIrIxkhp9uc: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 069 - Jesus Quebrou Os Meus Grilhões.mp4
# [download] 100% of    3.69MiB in 00:00:02 at 1.54MiB/s
# [download] Downloading item 70 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=iopf76IICaU
# [youtube] iopf76IICaU: Downloading webpage
# [youtube] iopf76IICaU: Downloading ios player API JSON
# [youtube] iopf76IICaU: Downloading web creator player API JSON
# [youtube] iopf76IICaU: Downloading m3u8 information
# [info] iopf76IICaU: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 070 - Cristo Jesus Vai Voltar.mp4
# [download] 100% of    4.78MiB in 00:00:02 at 2.32MiB/s
# [download] Downloading item 71 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=l7W0eFzWA4Q
# [youtube] l7W0eFzWA4Q: Downloading webpage
# [youtube] l7W0eFzWA4Q: Downloading ios player API JSON
# [youtube] l7W0eFzWA4Q: Downloading web creator player API JSON
# [youtube] l7W0eFzWA4Q: Downloading m3u8 information
# [info] l7W0eFzWA4Q: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 071 - Santo És Tu, Senhor.mp4
# [download] 100% of    3.47MiB in 00:00:02 at 1.69MiB/s
# [download] Downloading item 72 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Egn-KY6kah0
# [youtube] Egn-KY6kah0: Downloading webpage
# [youtube] Egn-KY6kah0: Downloading ios player API JSON
# [youtube] Egn-KY6kah0: Downloading web creator player API JSON
# [youtube] Egn-KY6kah0: Downloading m3u8 information
# [info] Egn-KY6kah0: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 072 - Rasgou se O Véu.mp4
# [download] 100% of    4.46MiB in 00:00:03 at 1.35MiB/s
# [download] Downloading item 73 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=wCDedpQPyvQ
# [youtube] wCDedpQPyvQ: Downloading webpage
# [youtube] wCDedpQPyvQ: Downloading ios player API JSON
# [youtube] wCDedpQPyvQ: Downloading web creator player API JSON
# [youtube] wCDedpQPyvQ: Downloading m3u8 information
# [info] wCDedpQPyvQ: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 073 - Vem, Vem A Mim.mp4
# [download] 100% of    5.36MiB in 00:00:04 at 1.29MiB/s
# [download] Downloading item 74 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Q7zIfmXcuVs
# [youtube] Q7zIfmXcuVs: Downloading webpage
# [youtube] Q7zIfmXcuVs: Downloading ios player API JSON
# [youtube] Q7zIfmXcuVs: Downloading web creator player API JSON
# [youtube] Q7zIfmXcuVs: Downloading m3u8 information
# [info] Q7zIfmXcuVs: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 074 - Cristo Virá.mp4
# [download] 100% of    3.51MiB in 00:00:02 at 1.72MiB/s
# [download] Downloading item 75 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=6VHPhNRM4dI
# [youtube] 6VHPhNRM4dI: Downloading webpage
# [youtube] 6VHPhNRM4dI: Downloading ios player API JSON
# [youtube] 6VHPhNRM4dI: Downloading web creator player API JSON
# [youtube] 6VHPhNRM4dI: Downloading m3u8 information
# [info] 6VHPhNRM4dI: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 075 - Em Jesus Tens A Palma da Vitória.mp4
# [download] 100% of    4.21MiB in 00:00:02 at 1.53MiB/s
# [download] Downloading item 76 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=iTVIP_xT1kA
# [youtube] iTVIP_xT1kA: Downloading webpage
# [youtube] iTVIP_xT1kA: Downloading ios player API JSON
# [youtube] iTVIP_xT1kA: Downloading web creator player API JSON
# [youtube] iTVIP_xT1kA: Downloading m3u8 information
# [info] iTVIP_xT1kA: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 076 - Vem, Ó Pródigo.mp4
# [download] 100% of    3.43MiB in 00:00:03 at 924.79KiB/s
# [download] Downloading item 77 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=8LlRCz-oelk
# [youtube] 8LlRCz-oelk: Downloading webpage
# [youtube] 8LlRCz-oelk: Downloading ios player API JSON
# [youtube] 8LlRCz-oelk: Downloading web creator player API JSON
# [youtube] 8LlRCz-oelk: Downloading m3u8 information
# [info] 8LlRCz-oelk: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 077 - Guarda O Contacto.mp4
# [download] 100% of    5.14MiB in 00:00:02 at 1.72MiB/s
# [download] Downloading item 78 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=AMVrJD3uHtY
# [youtube] AMVrJD3uHtY: Downloading webpage
# [youtube] AMVrJD3uHtY: Downloading ios player API JSON
# [youtube] AMVrJD3uHtY: Downloading web creator player API JSON
# [youtube] AMVrJD3uHtY: Downloading m3u8 information
# [info] AMVrJD3uHtY: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 078 - Meu Forte Redentor.mp4
# [download] 100% of    5.09MiB in 00:00:03 at 1.33MiB/s
# [download] Downloading item 79 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=sUdbBsltYaM
# [youtube] sUdbBsltYaM: Downloading webpage
# [youtube] sUdbBsltYaM: Downloading ios player API JSON
# [youtube] sUdbBsltYaM: Downloading web creator player API JSON
# [youtube] sUdbBsltYaM: Downloading m3u8 information
# [info] sUdbBsltYaM: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 079 - Sua Graça Me Basta.mp4
# [download] 100% of    4.09MiB in 00:00:02 at 1.43MiB/s
# [download] Downloading item 80 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=lepwpPk39cA
# [youtube] lepwpPk39cA: Downloading webpage
# [youtube] lepwpPk39cA: Downloading ios player API JSON
# [youtube] lepwpPk39cA: Downloading web creator player API JSON
# [youtube] lepwpPk39cA: Downloading m3u8 information
# [info] lepwpPk39cA: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 080 - Cristo Te Chama.mp4
# [download] 100% of    3.75MiB in 00:00:03 at 1.21MiB/s
# [download] Downloading item 81 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=bYOla2CZBR8
# [youtube] bYOla2CZBR8: Downloading webpage
# [youtube] bYOla2CZBR8: Downloading ios player API JSON
# [youtube] bYOla2CZBR8: Downloading web creator player API JSON
# [youtube] bYOla2CZBR8: Downloading m3u8 information
# [info] bYOla2CZBR8: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 081 - Pode Salvar.mp4
# [download] 100% of    4.13MiB in 00:00:03 at 1.36MiB/s
# [download] Downloading item 82 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=jfQxbcdTinA
# [youtube] jfQxbcdTinA: Downloading webpage
# [youtube] jfQxbcdTinA: Downloading ios player API JSON
# [youtube] jfQxbcdTinA: Downloading web creator player API JSON
# [youtube] jfQxbcdTinA: Downloading m3u8 information
# [info] jfQxbcdTinA: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 082 - Um Meigo Salvador.mp4
# [download] 100% of    4.34MiB in 00:00:02 at 1.81MiB/s
# [download] Downloading item 83 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=5455hPGKYPM
# [youtube] 5455hPGKYPM: Downloading webpage
# [youtube] 5455hPGKYPM: Downloading ios player API JSON
# [youtube] 5455hPGKYPM: Downloading web creator player API JSON
# [youtube] 5455hPGKYPM: Downloading m3u8 information
# [info] 5455hPGKYPM: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 083-  Não Posso Explicar.mp4
# [download] 100% of    2.97MiB in 00:00:03 at 774.14KiB/s
# [download] Downloading item 84 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=VH1QSK5gfIE
# [youtube] VH1QSK5gfIE: Downloading webpage
# [youtube] VH1QSK5gfIE: Downloading ios player API JSON
# [youtube] VH1QSK5gfIE: Downloading web creator player API JSON
# [youtube] VH1QSK5gfIE: Downloading m3u8 information
# [info] VH1QSK5gfIE: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 084 - O Grande Eu Sou.mp4
# [download] 100% of    5.57MiB in 00:00:04 at 1.30MiB/s
# [download] Downloading item 85 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=LZe0e1d8-Ag
# [youtube] LZe0e1d8-Ag: Downloading webpage
# [youtube] LZe0e1d8-Ag: Downloading ios player API JSON
# [youtube] LZe0e1d8-Ag: Downloading web creator player API JSON
# [youtube] LZe0e1d8-Ag: Downloading m3u8 information
# [info] LZe0e1d8-Ag: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 085 - Deixai Entrar O Espírito de Deus.mp4
# [download] 100% of    4.99MiB in 00:00:04 at 1.03MiB/s
# [download] Downloading item 86 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=3asHo_vSSsY
# [youtube] 3asHo_vSSsY: Downloading webpage
# [youtube] 3asHo_vSSsY: Downloading ios player API JSON
# [youtube] 3asHo_vSSsY: Downloading web creator player API JSON
# [youtube] 3asHo_vSSsY: Downloading m3u8 information
# [info] 3asHo_vSSsY: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 086  Satisfeito Com Cristo.mp4
# [download] 100% of    3.78MiB in 00:00:02 at 1.81MiB/s
# [download] Downloading item 87 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Jg4VnL62qPQ
# [youtube] Jg4VnL62qPQ: Downloading webpage
# [youtube] Jg4VnL62qPQ: Downloading ios player API JSON
# [youtube] Jg4VnL62qPQ: Downloading web creator player API JSON
# [youtube] Jg4VnL62qPQ: Downloading m3u8 information
# [info] Jg4VnL62qPQ: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 087 - Meu Testemunho.mp4
# [download] 100% of    4.90MiB in 00:00:03 at 1.58MiB/s
# [download] Downloading item 88 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=9q_bgcpSy6E
# [youtube] 9q_bgcpSy6E: Downloading webpage
# [youtube] 9q_bgcpSy6E: Downloading ios player API JSON
# [youtube] 9q_bgcpSy6E: Downloading web creator player API JSON
# [youtube] 9q_bgcpSy6E: Downloading m3u8 information
# [info] 9q_bgcpSy6E: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 088 - Revela A Nós, Senhor.mp4
# [download] 100% of    6.04MiB in 00:00:03 at 1.62MiB/s
# [download] Downloading item 89 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=WFAwjEgQmGU
# [youtube] WFAwjEgQmGU: Downloading webpage
# [youtube] WFAwjEgQmGU: Downloading ios player API JSON
# [youtube] WFAwjEgQmGU: Downloading web creator player API JSON
# [youtube] WFAwjEgQmGU: Downloading m3u8 information
# [info] WFAwjEgQmGU: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 089 - Sublime E Grande Amor.mp4
# [download] 100% of    5.93MiB in 00:00:03 at 1.65MiB/s
# [download] Downloading item 90 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=XLzWJ8vRrh0
# [youtube] XLzWJ8vRrh0: Downloading webpage
# [youtube] XLzWJ8vRrh0: Downloading ios player API JSON
# [youtube] XLzWJ8vRrh0: Downloading web creator player API JSON
# [youtube] XLzWJ8vRrh0: Downloading m3u8 information
# [info] XLzWJ8vRrh0: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 090 - Há Paz E Alegria.mp4
# [download] 100% of    2.51MiB in 00:00:02 at 1.15MiB/s
# [download] Downloading item 91 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=GBvMLjSEpvQ
# [youtube] GBvMLjSEpvQ: Downloading webpage
# [youtube] GBvMLjSEpvQ: Downloading ios player API JSON
# [youtube] GBvMLjSEpvQ: Downloading web creator player API JSON
# [youtube] GBvMLjSEpvQ: Downloading m3u8 information
# [info] GBvMLjSEpvQ: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 091 - Nívea Luz.mp4
# [download] 100% of    3.85MiB in 00:00:02 at 1.30MiB/s
# [download] Downloading item 92 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=_FYBPzA6uZI
# [youtube] _FYBPzA6uZI: Downloading webpage
# [youtube] _FYBPzA6uZI: Downloading ios player API JSON
# [youtube] _FYBPzA6uZI: Downloading web creator player API JSON
# [youtube] _FYBPzA6uZI: Downloading m3u8 information
# [info] _FYBPzA6uZI: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 092 - O Bondoso Salvador.mp4
# [download] 100% of    3.58MiB in 00:00:02 at 1.22MiB/s
# [download] Downloading item 93 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=t-nvlofFy8c
# [youtube] t-nvlofFy8c: Downloading webpage
# [youtube] t-nvlofFy8c: Downloading ios player API JSON
# [youtube] t-nvlofFy8c: Downloading web creator player API JSON
# [youtube] t-nvlofFy8c: Downloading m3u8 information
# [info] t-nvlofFy8c: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 093 - Há Trabalho Pronto.mp4
# [download] 100% of    6.98MiB in 00:00:03 at 2.29MiB/s
# [download] Downloading item 94 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=pB8MixeBX64
# [youtube] pB8MixeBX64: Downloading webpage
# [youtube] pB8MixeBX64: Downloading ios player API JSON
# [youtube] pB8MixeBX64: Downloading web creator player API JSON
# [youtube] pB8MixeBX64: Downloading m3u8 information
# [info] pB8MixeBX64: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 094 - Na Jerusalém de Deus.mp4
# [download] 100% of    5.32MiB in 00:00:03 at 1.66MiB/s
# [download] Downloading item 95 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=C-dVJZP9uQE
# [youtube] C-dVJZP9uQE: Downloading webpage
# [youtube] C-dVJZP9uQE: Downloading ios player API JSON
# [youtube] C-dVJZP9uQE: Downloading web creator player API JSON
# [youtube] C-dVJZP9uQE: Downloading m3u8 information
# [info] C-dVJZP9uQE: Downloading 1 format(s): 18
# [download] Destination: Harpa Cristã 095 - Ouve, Ó Pecador.mp4
# [download] 100% of    3.10MiB in 00:00:02 at 1.11MiB/s
# [download] Downloading item 96 of 636
# [youtube] Extracting URL: https://www.youtube.com/watch?v=1Oq9XarncfE
# [youtube] 1Oq9XarncfE: Downloading webpage
# [youtube] 1Oq9XarncfE: Downloading ios player API JSON
# [youtube] 1Oq9XarncfE: Downloading web creator player API JSON
# ...
# -> 1911                 return self.__process_playlist(ie_result, download)
#    1912             finally:
#    1913                 self._playlist_level -= 1
#
# /usr/local/lib/python3.10/dist-packages/yt_dlp/YoutubeDL.py in __process_playlist(self, ie_result, download)
#    2056                 f'of {self._format_screen(n_entries, self.Styles.EMPHASIS)}')
#    2057
# -> 2058             entry_result = self.__process_iterable_entry(entry, download, collections.ChainMap({
#    2059                 'playlist_index': playlist_index,
#    2060                 'playlist_autonumber': i + 1,
#
# /usr/local/lib/python3.10/dist-packages/yt_dlp/YoutubeDL.py in wrapper(self, *args, **kwargs)
#    1624             while True:
#    1625                 try:
# -> 1626                     return func(self, *args, **kwargs)
#    1627                 except (DownloadCancelled, LazyList.IndexError, PagedList.IndexError):
#    1628                     raise
#
# /usr/local/lib/python3.10/dist-packages/yt_dlp/YoutubeDL.py in __process_iterable_entry(self, entry, download, extra_info)
#    2088     @_handle_extraction_exceptions
#    2089     def __process_iterable_entry(self, entry, download, extra_info):
# -> 2090         return self.process_ie_result(
#    2091             entry, download=download, extra_info=extra_info)
#    2092
#
# /usr/local/lib/python3.10/dist-packages/yt_dlp/YoutubeDL.py in process_ie_result(self, ie_result, download, extra_info)
#    1859             # We have to add extra_info to the results because it may be
#    1860             # contained in a playlist
# -> 1861             return self.extract_info(
#    1862                 ie_result['url'], download,
#    1863                 ie_key=ie_result.get('ie_key'),
#
# /usr/local/lib/python3.10/dist-packages/yt_dlp/YoutubeDL.py in extract_info(self, url, download, ie_key, extra_info, process, force_generic_extractor)
#    1613                     raise ExistingVideoReached
#    1614                 break
# -> 1615             return self.__extract_info(url, self.get_info_extractor(key), download, extra_info, process)
#    1616         else:
#    1617             extractors_restricted = self.params.get('allowed_extractors') not in (None, ['default'])
#
# /usr/local/lib/python3.10/dist-packages/yt_dlp/YoutubeDL.py in wrapper(self, *args, **kwargs)
#    1624             while True:
#    1625                 try:
# -> 1626                     return func(self, *args, **kwargs)
#    1627                 except (DownloadCancelled, LazyList.IndexError, PagedList.IndexError):
#    1628                     raise
#
# /usr/local/lib/python3.10/dist-packages/yt_dlp/YoutubeDL.py in __extract_info(self, url, ie, download, extra_info, process)
#    1759
#    1760         try:
# -> 1761             ie_result = ie.extract(url)
#    1762         except UserNotLive as e:
#    1763             if process:
#
# /usr/local/lib/python3.10/dist-packages/yt_dlp/extractor/common.py in extract(self, url)
#     738                     self.to_screen('Extracting URL: %s' % (
#     739                         url if self.get_param('verbose') else truncate_string(url, 100, 20)))
# --> 740                     ie_result = self._real_extract(url)
#     741                     if ie_result is None:
#     742                         return None
#
# /usr/local/lib/python3.10/dist-packages/yt_dlp/extractor/youtube.py in _real_extract(self, url)
#    4335
#    4336         live_broadcast_details, live_status, streaming_data, formats, automatic_captions = \
# -> 4337             self._list_formats(video_id, microformats, video_details, player_responses, player_url, duration)
#    4338         if live_status == 'post_live':
#    4339             self.write_debug(f'{video_id}: Video is in Post-Live Manifestless mode')
#
# /usr/local/lib/python3.10/dist-packages/yt_dlp/extractor/youtube.py in _list_formats(self, video_id, microformats, video_details, player_responses, player_url, duration)
#    4238                        else None)
#    4239         streaming_data = traverse_obj(player_responses, (..., 'streamingData'))
# -> 4240         *formats, subtitles = self._extract_formats_and_subtitles(streaming_data, video_id, player_url, live_status, duration)
#    4241         if all(f.get('has_drm') for f in formats):
#    4242             # If there are no formats that definitely don't have DRM, all have DRM
#
# /usr/local/lib/python3.10/dist-packages/yt_dlp/extractor/youtube.py in _extract_formats_and_subtitles(self, streaming_data, video_id, player_url, live_status, duration)
#    3990                     decrypt_nsig = self._cached(self._decrypt_nsig, 'nsig', query['n'][0])
#    3991                     fmt_url = update_url_query(fmt_url, {
# -> 3992                         'n': decrypt_nsig(query['n'][0], video_id, player_url),
#    3993                     })
#    3994                 except ExtractorError as e:
#
# /usr/local/lib/python3.10/dist-packages/yt_dlp/extractor/youtube.py in inner(*args, **kwargs)
#    3120             if cache_id not in self._player_cache:
#    3121                 try:
# -> 3122                     self._player_cache[cache_id] = func(*args, **kwargs)
#    3123                 except ExtractorError as e:
#    3124                     self._player_cache[cache_id] = e
#
# /usr/local/lib/python3.10/dist-packages/yt_dlp/extractor/youtube.py in _decrypt_nsig(self, s, video_id, player_url)
#    3155         try:
#    3156             extract_nsig = self._cached(self._extract_n_function_from_code, 'nsig func', player_url)
# -> 3157             ret = extract_nsig(jsi, func_code)(s)
#    3158         except JSInterpreter.Exception as e:
#    3159             try:
#
# /usr/local/lib/python3.10/dist-packages/yt_dlp/extractor/youtube.py in extract_nsig(s)
#    3237         def extract_nsig(s):
#    3238             try:
# -> 3239                 ret = func([s])
#    3240             except JSInterpreter.Exception:
#    3241                 raise
#
# /usr/local/lib/python3.10/dist-packages/yt_dlp/jsinterp.py in resf(args, kwargs, allow_recursion)
#     866             global_stack[0].update(kwargs)
#     867             var_stack = LocalNameSpace(*global_stack)
# --> 868             ret, should_abort = self.interpret_statement(code.replace('\n', ' '), var_stack, allow_recursion - 1)
#     869             if should_abort:
#     870                 return ret
#
# /usr/local/lib/python3.10/dist-packages/yt_dlp/jsinterp.py in interpret_statement(self, stmt, local_vars, allow_recursion, *args, **kwargs)
#     183                 cls.write(stmt, level=allow_recursion)
#     184             try:
# --> 185                 ret, should_ret = f(self, stmt, local_vars, allow_recursion, *args, **kwargs)
#     186             except Exception as e:
#     187                 if cls.ENABLED:
#
# /usr/local/lib/python3.10/dist-packages/yt_dlp/jsinterp.py in interpret_statement(self, stmt, local_vars, allow_recursion)
#     438             err = None
#     439             try:
# --> 440                 ret, should_abort = self.interpret_statement(try_expr, local_vars, allow_recursion)
#     441                 if should_abort:
#     442                     return ret, True
#
# /usr/local/lib/python3.10/dist-packages/yt_dlp/jsinterp.py in interpret_statement(self, stmt, local_vars, allow_recursion, *args, **kwargs)
#     183                 cls.write(stmt, level=allow_recursion)
#     184             try:
# --> 185                 ret, should_ret = f(self, stmt, local_vars, allow_recursion, *args, **kwargs)
#     186             except Exception as e:
#     187                 if cls.ENABLED:
#
# /usr/local/lib/python3.10/dist-packages/yt_dlp/jsinterp.py in interpret_statement(self, stmt, local_vars, allow_recursion)
#     459             if m:
#     460                 sub_expr, expr = self._separate_at_paren(expr[m.end() - 1:])
# --> 461                 ret, should_abort = self.interpret_statement(sub_expr, local_vars, allow_recursion)
#     462                 if should_abort:
#     463                     return ret, True
#
# /usr/local/lib/python3.10/dist-packages/yt_dlp/jsinterp.py in interpret_statement(self, stmt, local_vars, allow_recursion, *args, **kwargs)
#     183                 cls.write(stmt, level=allow_recursion)
#     184             try:
# --> 185                 ret, should_ret = f(self, stmt, local_vars, allow_recursion, *args, **kwargs)
#     186             except Exception as e:
#     187                 if cls.ENABLED:
#
# /usr/local/lib/python3.10/dist-packages/yt_dlp/jsinterp.py in interpret_statement(self, stmt, local_vars, allow_recursion)
#     530         if len(sub_expressions) > 1:
#     531             for sub_expr in sub_expressions:
# --> 532                 ret, should_abort = self.interpret_statement(sub_expr, local_vars, allow_recursion)
#     533                 if should_abort:
#     534                     return ret, True
#
# /usr/local/lib/python3.10/dist-packages/yt_dlp/jsinterp.py in interpret_statement(self, stmt, local_vars, allow_recursion, *args, **kwargs)
#     183                 cls.write(stmt, level=allow_recursion)
#     184             try:
# --> 185                 ret, should_ret = f(self, stmt, local_vars, allow_recursion, *args, **kwargs)
#     186             except Exception as e:
#     187                 if cls.ENABLED:
#
# /usr/local/lib/python3.10/dist-packages/yt_dlp/jsinterp.py in interpret_statement(self, stmt, local_vars, allow_recursion)
#     619                 continue
#     620             left_val = self.interpret_expression(op.join(separated), local_vars, allow_recursion)
# --> 621             return self._operator(op, left_val, right_expr, expr, local_vars, allow_recursion), should_return
#     622
#     623         if m and m.group('attribute'):
#
# /usr/local/lib/python3.10/dist-packages/yt_dlp/jsinterp.py in _operator(self, op, left_val, right_expr, expr, local_vars, allow_recursion)
#     300             right_expr = _js_ternary(left_val, *self._separate(right_expr, ':', 1))
#     301
# --> 302         right_val = self.interpret_expression(right_expr, local_vars, allow_recursion)
#     303         if not _OPERATORS.get(op):
#     304             return right_val
#
# /usr/local/lib/python3.10/dist-packages/yt_dlp/jsinterp.py in interpret_expression(self, expr, local_vars, allow_recursion)
#     788
#     789     def interpret_expression(self, expr, local_vars, allow_recursion):
# --> 790         ret, should_return = self.interpret_statement(expr, local_vars, allow_recursion)
#     791         if should_return:
#     792             raise self.Exception('Cannot return from an expression', expr)
#
# /usr/local/lib/python3.10/dist-packages/yt_dlp/jsinterp.py in interpret_statement(self, stmt, local_vars, allow_recursion, *args, **kwargs)
#     183                 cls.write(stmt, level=allow_recursion)
#     184             try:
# --> 185                 ret, should_ret = f(self, stmt, local_vars, allow_recursion, *args, **kwargs)
#     186             except Exception as e:
#     187                 if cls.ENABLED:
#
# /usr/local/lib/python3.10/dist-packages/yt_dlp/jsinterp.py in interpret_statement(self, stmt, local_vars, allow_recursion)
#     776         elif m and m.group('function'):
#     777             fname = m.group('fname')
# --> 778             argvals = [self.interpret_expression(v, local_vars, allow_recursion)
#     779                        for v in self._separate(m.group('args'))]
#     780             if fname in local_vars:
#
# /usr/local/lib/python3.10/dist-packages/yt_dlp/jsinterp.py in <listcomp>(.0)
#     776         elif m and m.group('function'):
#     777             fname = m.group('fname')
# --> 778             argvals = [self.interpret_expression(v, local_vars, allow_recursion)
#     779                        for v in self._separate(m.group('args'))]
#     780             if fname in local_vars:
#
# /usr/local/lib/python3.10/dist-packages/yt_dlp/jsinterp.py in interpret_expression(self, expr, local_vars, allow_recursion)
#     788
#     789     def interpret_expression(self, expr, local_vars, allow_recursion):
# --> 790         ret, should_return = self.interpret_statement(expr, local_vars, allow_recursion)
#     791         if should_return:
#     792             raise self.Exception('Cannot return from an expression', expr)
#
# /usr/local/lib/python3.10/dist-packages/yt_dlp/jsinterp.py in interpret_statement(self, stmt, local_vars, allow_recursion, *args, **kwargs)
#     183                 cls.write(stmt, level=allow_recursion)
#     184             try:
# --> 185                 ret, should_ret = f(self, stmt, local_vars, allow_recursion, *args, **kwargs)
#     186             except Exception as e:
#     187                 if cls.ENABLED:
#
# /usr/local/lib/python3.10/dist-packages/yt_dlp/jsinterp.py in interpret_statement(self, stmt, local_vars, allow_recursion)
#     779                        for v in self._separate(m.group('args'))]
#     780             if fname in local_vars:
# --> 781                 return local_vars[fname](argvals, allow_recursion=allow_recursion), should_return
#     782             elif fname not in self._functions:
#     783                 self._functions[fname] = self.extract_function(fname)
#
# /usr/local/lib/python3.10/dist-packages/yt_dlp/utils/_utils.py in __call__(self, *args, **kwargs)
#    5001
#    5002     def __call__(self, *args, **kwargs):
# -> 5003         return self.func(*args, **kwargs)
#    5004
#    5005     @classmethod
#
# /usr/local/lib/python3.10/dist-packages/yt_dlp/jsinterp.py in resf(args, kwargs, allow_recursion)
#     866             global_stack[0].update(kwargs)
#     867             var_stack = LocalNameSpace(*global_stack)
# --> 868             ret, should_abort = self.interpret_statement(code.replace('\n', ' '), var_stack, allow_recursion - 1)
#     869             if should_abort:
#     870                 return ret
#
# /usr/local/lib/python3.10/dist-packages/yt_dlp/jsinterp.py in interpret_statement(self, stmt, local_vars, allow_recursion, *args, **kwargs)
#     183                 cls.write(stmt, level=allow_recursion)
#     184             try:
# --> 185                 ret, should_ret = f(self, stmt, local_vars, allow_recursion, *args, **kwargs)
#     186             except Exception as e:
#     187                 if cls.ENABLED:
#
# /usr/local/lib/python3.10/dist-packages/yt_dlp/jsinterp.py in interpret_statement(self, stmt, local_vars, allow_recursion)
#     488                     break
#     489                 try:
# --> 490                     ret, should_abort = self.interpret_statement(body, local_vars, allow_recursion)
#     491                     if should_abort:
#     492                         return ret, True
#
# /usr/local/lib/python3.10/dist-packages/yt_dlp/jsinterp.py in interpret_statement(self, stmt, local_vars, allow_recursion, *args, **kwargs)
#     183                 cls.write(stmt, level=allow_recursion)
#     184             try:
# --> 185                 ret, should_ret = f(self, stmt, local_vars, allow_recursion, *args, **kwargs)
#     186             except Exception as e:
#     187                 if cls.ENABLED:
#
# /usr/local/lib/python3.10/dist-packages/yt_dlp/jsinterp.py in interpret_statement(self, stmt, local_vars, allow_recursion)
#     505                 matched = False
#     506                 for item in items:
# --> 507                     case, stmt = (i.strip() for i in self._separate(item, ':', 1))
#     508                     if default:
#     509                         matched = matched or case == 'default'
#
# /usr/local/lib/python3.10/dist-packages/yt_dlp/jsinterp.py in <genexpr>(.0)
#     505                 matched = False
#     506                 for item in items:
# --> 507                     case, stmt = (i.strip() for i in self._separate(item, ':', 1))
#     508                     if default:
#     509                         matched = matched or case == 'default'
#
# /usr/local/lib/python3.10/dist-packages/yt_dlp/jsinterp.py in _separate(expr, delim, max_split)
#     251         in_quote, escaping, after_op, in_regex_char_group = None, False, True, False
#     252         for idx, char in enumerate(expr):
# --> 253             if not in_quote and char in _MATCHING_PARENS:
#     254                 counters[_MATCHING_PARENS[char]] += 1
#     255             elif not in_quote and char in counters:
#
# KeyboardInterrupt:
